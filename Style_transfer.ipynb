# %% [markdown]
# <a href="https://colab.research.google.com/github/jevggenija/Style_extraction/blob/main/Style_transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=2
b=3
# !git branch
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# !ls -la
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 May 26 13:25 .
# drwxr-xr-x 1 root root 4096 Jun  2 10:59 ..
# drwxr-xr-x 4 root root 4096 May 26 13:25 .config
# drwxr-xr-x 1 root root 4096 May 26 13:25 sample_data

# %%
# !git clone https://github.com/jevggenija/Style_extraction.git
# Out:
# Cloning into 'Style_extraction'...
# ...

# %%
# %cd /content/Style_extraction
# Out:
# /content/Style_extraction

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .
# !git commit -m "Initial commit"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@169166131b0b.(none)')

# %%
# !git remote -v
# Out:
# origin	https://github.com/jevggenija/Style_extraction.git (fetch)
# origin	https://github.com/jevggenija/Style_extraction.git (push)

# %%
# !git status
# !git log --oneline
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)
# fatal: your current branch 'main' does not have any commits yet

# %%
# !pwd
# !ls -la
# Out:
# /content/Style_extraction
# total 12
# drwxr-xr-x 3 root root 4096 Jun  2 11:04 .
# drwxr-xr-x 1 root root 4096 Jun  2 11:04 ..
# drwxr-xr-x 7 root root 4096 Jun  2 11:07 .git

# %%
# !echo "# Style_extraction" > README.md
# !git add README.md
# !git commit -m "Initial commit"
# !git push -u origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@169166131b0b.(none)')
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/jevggenija/Style_extraction.git'
